# %%
import pandas as pd
import numpy as np
import random
df = pd.read_pickle('data_full.pkl')

# %%
df.head()
# Out:
#                                      id  \
# 0  b8645f24-32b3-4732-b0ee-99db249bcd79
# 1  d9565025-0798-4477-aaad-b9effb0fc974
# 2  dcafd902-0a03-4617-bfad-42f6f4fa0513
# 3  da4cd658-bca1-4935-b9c3-98d65030e818
# 4  b854842f-4701-4c1d-9613-a6e919617f57
#
#                                             question  \
# 0  Sumita Khatri wrote a research report and foll...
# 1  Aryana Reid, CFA, is a private wealth manager....
# 2  Kent Miller is an investment adviser at UBN In...
# 3  Justin Zoghlin, CFA, was hired as a wealth man...
# 4  Rani Kaporwala, CFA, an analyst at Smart Secur...
#
#                                              options  \
# 0  [No., Yes, relating to performance presentatio...
# 1  [Publish the post and send it as a mail to the...
# 2  [determine Hartford’s needs, objectives, and t...
# 3  [Serving the religious community., Managing no...
# 4  [No., Yes, relating to communications with cli...
#
#                             _category  \
# ...

# %%
# df['id'] = df.index

# # Function to create a random review state array
# def create_review_state():
#     states = [0]
#     for _ in range(random.randint(1, 10)):  # Random length of the array
#         if states[-1] == 3:
#             states.append(2)
#         else:
#             states.append(states[-1] + 1)
#     return states

# # Function to create a random array of numbers less than 30
# def create_review_time(length):
#     return [random.randint(1, 29) for _ in range(length)]

# # Add new columns
# df['review_state'] = df.apply(lambda x: create_review_state(), axis=1)
# df['review_time'] = df['review_state'].apply(lambda x: create_review_time(len(x)))
# df['z_scores'] = df['review_state'].apply(lambda x: [random.uniform(0, 1) for _ in x])
# df['s_score'] = np.random.uniform(0, 1, df.shape[0])
# df['Q_score'] = np.random.uniform(0, 1, df.shape[0])

# df.to_pickle("data.pkl")

# df
# Out:
#     id                                           question  \
# 0    0  Sumita Khatri wrote a research report and foll...
# 1    1  Aryana Reid, CFA, is a private wealth manager....
# 2    2  Kent Miller is an investment adviser at UBN In...
# 3    3  Justin Zoghlin, CFA, was hired as a wealth man...
# 4    4  Rani Kaporwala, CFA, an analyst at Smart Secur...
# 5    5  Cara Knightly is a much respected portfolio ma...
# 6    6  Andy McCarthy, CFA, resigns from his position ...
# 7    7  During lunch with his friend, who is an analys...
# 8    8  Which of the following is least likely correct...
# 9    9  Stewart is an analyst at a small investment fi...
# 10  10  Which of the following actions is least likely...
# 11  11  Which of the following is not correct about ve...
# 12  12  Which of the following is not a requirement of...
# 13  13  Cassandra Turnbull is planning a college fund ...
# 14  14  An equity analyst has categorized some stocks ...
# ...
